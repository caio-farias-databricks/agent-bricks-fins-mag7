# %%
# %run ./resources/brick_setup_functions

# %%
from databricks.sdk import WorkspaceClient
w = WorkspaceClient()

brick = AgentBricksManager(w)

# %%
knowledge_sources =             {
                "files_source": {
                    "name": "10ks",
                    "type": "files",
                    "description": "10ls for magnificent seven",
                    "files": {"path": "/Volumes/main/fins_agent_bricks_demo/magnificent_seven_unstructured_data/10k/"}
                }
            }
ka_brick = brick.ka_create(name='finsdemoagent',
                knowledge_sources=knowledge_sources,
                description='financial q and a agent')

# %%
# tile_id = ka_brick['knowledge_assistant']['tile']['tile_id']
tile_id = '70ce7527-4231-41a5-8ab4-5ca3221ec007'

# %%
brick.ka_get_endpoint_status(tile_id)

# %%
brick.ka_is_ready_for_update(tile_id)

# %%
brick.ka_wait_for_ready_status(tile_id)
